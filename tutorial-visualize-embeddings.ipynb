# %% [markdown]
# # Visualizing word embeddings : Deep Learning for NLP embeddings.
#
# This notebook will guide you through the implementation of Word2Vec, a popular model used in Natural Language Processing (NLP) to capture semantic meaning from text. We will apply this model to a dataset and visualize the learned word embeddings.

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ## Tutorial
#
# In this notebook, we will apply the Word2Vec model to a text dataset. The Word2Vec model learns to represent words in a continuous vector space, where semantically similar words are mapped to nearby points. We will walk through the following steps:
#
# 1. **Download the Training Data:** We'll start by downloading a large text corpus for training.
# 2. **Set up Word2Vec in TensorFlow:** We'll configure the Word2Vec model using TensorFlow, a popular machine learning library.
# 3. **Train the Model:** We'll train the Word2Vec model on the dataset to learn word embeddings.
# 4. **Visualize the Embeddings:** Finally, we'll visualize the learned word embeddings using dimensionality reduction techniques.

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ### Step 1: Download the Dataset
#
# To train our Word2Vec model, we need a large text corpus. In this step, we will download the "text8" dataset, a popular dataset used for training word embeddings. This dataset contains 100 MB of English Wikipedia text from 2006, which is commonly used in NLP tasks.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# > **Note:** While the dataset is being downloaded, feel free to look ahead at the upcoming code cells to get a sense of what we'll be doing next.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# ### Observations on Preprocessing
#
# - **Case and Punctuation:** Notice that none of the words in our dataset are capitalized, and there is no punctuation. This is likely due to preprocessing steps taken before we acquired the dataset, which ensures uniformity in the text.
# - **Preprocessing Considerations:** Preprocessing is a crucial part of NLP tasks, and its specifics depend on the data and the intended use. For instance, while we're working with unigrams (single words), other tasks might benefit from encoding n-grams (combinations of words) to capture context better.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %% [markdown]
# Now that we have our text data, the next step is to build a dictionary. This dictionary will map each unique word in our dataset to a unique integer code.
#
# Additionally, we'll keep track of the frequency of each word, which will help us prioritize the most common words.

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# ### Understanding the Key Variables
#
# - **`data`:** A list of integer codes representing the words in the original text. Each word is replaced by its corresponding code from the `dictionary`.
# - **`count`:** A list of tuples where each tuple contains a word and its frequency count in the dataset.
# - **`dictionary`:** A dictionary mapping each word to its unique integer code.
# - **`reverse_dictionary`:** A reverse mapping that converts integer codes back to their corresponding words.

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Least common words:')
print(*count[-5:], sep="\n")
# Out:
# Least common words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ### Step 3: Generate a Training Batch for the Skip-Gram Model
#
# In this step, we'll create a function to generate training batches for our skip-gram model. The skip-gram model is a variant of Word2Vec that predicts the context words given a target word. This function will help us prepare the data in the correct format for training the model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----
#
# The Skip-Gram model is a type of neural network model used in Natural Language Processing (NLP) to learn distributed representations of words, commonly known as word embeddings.
#
# Word embeddings are dense vector representations of words that capture semantic relationships between them, meaning that words with similar meanings are mapped to similar points in the vector space.
#
# ### How the Skip-Gram Model Works
# The goal of the Skip-Gram model is to predict the context words given a target word. Here's how it works:
#
# Input: The model takes a single word (the target word) from the text as input.
#
# Output: The model is trained to predict words that are likely to appear in the context of the target word within a specified window of words before and after the target word. This context window is typically referred to as the "skip window."
#
# For example, if the sentence is "The cat sat on the mat," and the target word is "sat," the model might be asked to predict the words "The," "cat," "on," and "the," which appear around "sat."

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
import tensorflow.compat.v1 as v1

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()
# Out:
# WARNING:tensorflow:From C:\Users\santi\AppData\Local\Temp\ipykernel_84764\701590837.py:6: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\santi\AppData\Local\Temp\ipykernel_84764\701590837.py:36: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  293.01031494140625
# Nearest to 'that': arbroath, sony, lana, homily,
# Nearest to 'after': nepos, algeria, consequences, jahangir,
# Nearest to 's': kops, knossos, flagpole, elysium,
# Nearest to 'other': digamma, disgusting, celebrates, encha,
# Nearest to 'american': foreshadowing, rated, funchal, angel,
# Nearest to 'would': busby, khyber, stampede, topalov,
# Nearest to 'or': uranus, outnumbered, breaker, education,
# Nearest to 'from': greenwich, falsification, worsening, plosives,
# Nearest to 'by': olney, boredom, milken, godless,
# Nearest to 'their': ani, utrecht, remit, activex,
# Nearest to 'his': conjunction, homeric, aurangzeb, explicated,
# Nearest to 'have': anna, david, confound, motilal,
# Nearest to 'no': oghuz, stresemann, technocrats, still,
# Nearest to 'is': fighting, confiscation, switching, mendeleev,
# Nearest to 'more': warp, refuse, headquarters, colloquially,
# Nearest to 'use': podcast, forti, orestes, shaykh,
#
# Average loss at step  2000 :  113.01480139350892
# Nearest to 'that': dispelling, communism, seven, sounds,
# Nearest to 'after': algeria, worked, seven, ehret,
# Nearest to 's': atomic, praised, they, far,
# Nearest to 'other': vs, letter, causes, king,
# Nearest to 'american': eu, remaining, foreshadowing, t,
# Nearest to 'would': vs, true, weekly, UNK,
# Nearest to 'or': abu, n, decades, need,
# Nearest to 'from': alien, vs, her, vast,
# Nearest to 'by': robert, way, term, country,
# Nearest to 'their': its, all, sections, natural,
# Nearest to 'his': with, gold, vineyards, humans,
# Nearest to 'have': vs, david, essay, ethical,
# Nearest to 'no': still, vs, ask, spanish,
# Nearest to 'is': named, land, populous, fighting,
# Nearest to 'more': refuse, austin, built, album,
# Nearest to 'use': vs, alien, cities, jpg,
#
# Average loss at step  4000 :  52.623388206481934
# Nearest to 'that': screen, communism, reached, dispelling,
# Nearest to 'after': algeria, seven, worked, argument,
# Nearest to 's': pleas, agave, anteaters, born,
# Nearest to 'other': vs, solstice, boroughs, kantian,
# Nearest to 'american': sleep, remaining, leakey, eu,
# Nearest to 'would': width, vs, true, stampede,
# Nearest to 'or': n, ha, decades, abu,
# Nearest to 'from': of, alien, ads, vs,
# Nearest to 'by': boredom, way, robert, term,
# Nearest to 'their': its, frederick, sections, remaining,
# Nearest to 'his': with, december, ss, the,
# Nearest to 'have': vs, david, anna, essay,
# Nearest to 'no': still, ask, spanish, al,
# Nearest to 'is': baseball, and, caught, populous,
# Nearest to 'more': refuse, ate, headquarters, austin,
# Nearest to 'use': net, vs, cities, emergence,
#
# Average loss at step  6000 :  33.69667497968674
# Nearest to 'that': screen, communism, and, dispelling,
# Nearest to 'after': algeria, seven, consequences, argument,
# Nearest to 's': pleas, agave, zero, cardinality,
# Nearest to 'other': vs, occurrence, solstice, causes,
# Nearest to 'american': sleep, eu, leakey, remaining,
# Nearest to 'would': lafayette, width, boolean, stampede,
# Nearest to 'or': n, ha, positive, decades,
# Nearest to 'from': of, in, bremer, and,
# Nearest to 'by': way, in, robert, boredom,
# Nearest to 'their': its, mya, the, all,
# Nearest to 'his': the, ss, december, bottling,
# Nearest to 'have': vs, david, anna, essay,
# Nearest to 'no': ask, still, listened, al,
# Nearest to 'is': are, we, caught, administration,
# Nearest to 'more': refuse, headquarters, warp, ate,
# Nearest to 'use': net, vs, emergence, cities,
#
# Average loss at step  8000 :  23.36971906852722
# Nearest to 'that': and, UNK, communism, reached,
# Nearest to 'after': algeria, archie, consequences, argument,
# Nearest to 's': and, zero, agave, UNK,
# Nearest to 'other': UNK, vs, occurrence, solstice,
# Nearest to 'american': eu, phi, remaining, leakey,
# Nearest to 'would': lafayette, UNK, hardly, width,
# Nearest to 'or': n, UNK, and, archie,
# Nearest to 'from': of, in, and, UNK,
# Nearest to 'by': in, boredom, UNK, and,
# Nearest to 'their': its, archie, the, lnot,
# Nearest to 'his': the, ss, ugly, accounts,
# Nearest to 'have': vs, papyrus, essay, anna,
# Nearest to 'no': ask, still, UNK, archie,
# Nearest to 'is': was, UNK, are, in,
# Nearest to 'more': refuse, headquarters, a, ate,
# Nearest to 'use': phi, net, confederates, cities,
#
# Average loss at step  10000 :  18.06140766429901
# Nearest to 'that': and, marple, communism, which,
# Nearest to 'after': algeria, archie, seven, consequences,
# Nearest to 's': and, zero, phi, cardinality,
# Nearest to 'other': celebrates, vs, occurrence, solstice,
# Nearest to 'american': eu, remaining, lovelace, dynasties,
# Nearest to 'would': lafayette, width, hardly, boolean,
# Nearest to 'or': and, n, archie, the,
# Nearest to 'from': in, and, of, before,
# Nearest to 'by': in, and, boredom, archie,
# Nearest to 'their': its, the, archie, lnot,
# Nearest to 'his': the, bckgr, gold, ss,
# Nearest to 'have': vs, were, papyrus, essay,
# Nearest to 'no': ask, still, a, greenland,
# Nearest to 'is': was, are, and, in,
# Nearest to 'more': refuse, a, headquarters, ate,
# Nearest to 'use': phi, mathbf, candidates, net,
#
# Average loss at step  12000 :  14.254746751070023
# Nearest to 'that': and, which, communism, marple,
# Nearest to 'after': algeria, archie, seven, consequences,
# Nearest to 's': zero, and, of, agave,
# Nearest to 'other': celebrates, occurrence, vs, solstice,
# Nearest to 'american': and, eu, remaining, lovelace,
# Nearest to 'would': lafayette, hardly, width, weekly,
# Nearest to 'or': and, n, archie, the,
# Nearest to 'from': in, and, of, before,
# Nearest to 'by': in, and, boredom, is,
# Nearest to 'their': its, the, archie, all,
# Nearest to 'his': the, hbox, bckgr, december,
# Nearest to 'have': were, vs, essay, anna,
# Nearest to 'no': ask, still, a, greenland,
# Nearest to 'is': was, are, in, archie,
# Nearest to 'more': refuse, a, headquarters, ate,
# Nearest to 'use': phi, mathbf, candidates, conclusions,
#
# Average loss at step  14000 :  11.784669340491295
# Nearest to 'that': dasyprocta, and, operatorname, which,
# Nearest to 'after': circ, algeria, archie, operatorname,
# Nearest to 's': zero, and, of, cardinality,
# Nearest to 'other': celebrates, occurrence, vs, gum,
# Nearest to 'american': and, foreshadowing, one, conquests,
# Nearest to 'would': operatorname, hardly, lafayette, width,
# Nearest to 'or': and, dasyprocta, archie, operatorname,
# Nearest to 'from': in, of, and, operatorname,
# Nearest to 'by': dasyprocta, and, in, is,
# Nearest to 'their': the, its, archie, all,
# Nearest to 'his': the, hbox, a, ugly,
# Nearest to 'have': were, essay, vs, anna,
# Nearest to 'no': a, still, ask, greenland,
# Nearest to 'is': was, are, dasyprocta, in,
# Nearest to 'more': refuse, a, headquarters, ate,
# Nearest to 'use': phi, operatorname, circ, mathbf,
#
# Average loss at step  16000 :  9.945998638272286
# Nearest to 'that': dasyprocta, which, and, operatorname,
# Nearest to 'after': circ, algeria, archie, in,
# Nearest to 's': and, zero, of, the,
# Nearest to 'other': celebrates, occurrence, meridians, disgusting,
# Nearest to 'american': and, foreshadowing, agouti, keynote,
# Nearest to 'would': hardly, operatorname, width, lafayette,
# Nearest to 'or': and, dasyprocta, operatorname, archie,
# Nearest to 'from': in, of, and, with,
# Nearest to 'by': dasyprocta, and, in, is,
# Nearest to 'their': its, the, his, archie,
# Nearest to 'his': the, hbox, a, their,
# Nearest to 'have': were, essay, gollancz, anjou,
# Nearest to 'no': a, ask, still, greenland,
# Nearest to 'is': was, are, dasyprocta, agouti,
# Nearest to 'more': refuse, a, headquarters, ate,
# Nearest to 'use': phi, operatorname, circ, mathbf,
#
# Average loss at step  18000 :  8.52805940207839
# Nearest to 'that': dasyprocta, which, operatorname, and,
# Nearest to 'after': circ, algeria, archie, seven,
# Nearest to 's': zero, and, the, cardinality,
# Nearest to 'other': celebrates, occurrence, meridians, disgusting,
# Nearest to 'american': and, one, foreshadowing, keynote,
# Nearest to 'would': hardly, operatorname, width, rerum,
# Nearest to 'or': and, dasyprocta, operatorname, nine,
# Nearest to 'from': in, and, of, on,
# Nearest to 'by': dasyprocta, in, and, was,
# Nearest to 'their': its, the, his, archie,
# Nearest to 'his': the, their, a, hbox,
# Nearest to 'have': were, be, anjou, essay,
# Nearest to 'no': a, still, ask, greenland,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': refuse, a, ate, headquarters,
# Nearest to 'use': phi, orestes, operatorname, circ,
#
# Average loss at step  20000 :  8.040035239458085
# Nearest to 'that': which, and, dasyprocta, operatorname,
# Nearest to 'after': algeria, circ, archie, salt,
# Nearest to 's': zero, and, the, cardinality,
# Nearest to 'other': meridians, celebrates, occurrence, gum,
# Nearest to 'american': and, foreshadowing, keynote, english,
# Nearest to 'would': hardly, operatorname, width, rerum,
# Nearest to 'or': and, dasyprocta, the, operatorname,
# Nearest to 'from': in, and, for, of,
# Nearest to 'by': was, in, is, dasyprocta,
# Nearest to 'their': the, its, his, all,
# Nearest to 'his': the, their, s, a,
# Nearest to 'have': were, anjou, be, and,
# Nearest to 'no': a, still, ask, the,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': refuse, a, headquarters, ate,
# Nearest to 'use': phi, orestes, operatorname, mathbf,
#
# Average loss at step  22000 :  6.880430300116539
# Nearest to 'that': which, dasyprocta, operatorname, and,
# Nearest to 'after': circ, archie, algeria, seven,
# Nearest to 's': and, zero, cardinality, agave,
# Nearest to 'other': meridians, celebrates, occurrence, gum,
# Nearest to 'american': foreshadowing, and, keynote, abet,
# Nearest to 'would': may, operatorname, hardly, width,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, and, with, for,
# Nearest to 'by': was, in, dasyprocta, with,
# Nearest to 'their': its, the, his, all,
# Nearest to 'his': the, their, s, a,
# Nearest to 'have': were, be, has, anjou,
# Nearest to 'no': a, still, ask, it,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': refuse, a, headquarters, most,
# Nearest to 'use': phi, orestes, abet, operatorname,
#
# Average loss at step  24000 :  6.877984012365341
# Nearest to 'that': which, dasyprocta, operatorname, communism,
# Nearest to 'after': circ, archie, algeria, salt,
# Nearest to 's': and, zero, agave, cardinality,
# Nearest to 'other': meridians, pcm, celebrates, gum,
# Nearest to 'american': and, foreshadowing, sleep, keynote,
# Nearest to 'would': may, operatorname, could, hardly,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, of, on, and,
# Nearest to 'by': was, in, with, dasyprocta,
# Nearest to 'their': its, the, his, all,
# Nearest to 'his': the, their, s, hbox,
# Nearest to 'have': were, has, are, be,
# Nearest to 'no': a, still, ask, it,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': refuse, a, most, headquarters,
# Nearest to 'use': phi, mishnayot, operatorname, abet,
#
# Average loss at step  26000 :  6.764095171332359
# Nearest to 'that': which, dasyprocta, operatorname, disappeared,
# Nearest to 'after': circ, archie, in, seven,
# Nearest to 's': zero, and, or, the,
# Nearest to 'other': celebrates, pcm, meridians, sponsors,
# Nearest to 'american': and, foreshadowing, english, canadian,
# Nearest to 'would': may, could, hardly, operatorname,
# Nearest to 'or': and, dasyprocta, operatorname, UNK,
# Nearest to 'from': in, of, before, for,
# Nearest to 'by': was, in, dasyprocta, with,
# Nearest to 'their': the, its, his, archie,
# Nearest to 'his': the, their, s, her,
# Nearest to 'have': were, has, are, had,
# Nearest to 'no': a, still, ask, it,
# Nearest to 'is': was, has, are, dasyprocta,
# Nearest to 'more': refuse, a, most, headquarters,
# Nearest to 'use': phi, mishnayot, orestes, operatorname,
#
# Average loss at step  28000 :  6.44853949701786
# Nearest to 'that': which, dasyprocta, operatorname, disappeared,
# Nearest to 'after': circ, archie, algeria, seven,
# Nearest to 's': and, zero, amalthea, the,
# Nearest to 'other': celebrates, pcm, meridians, gum,
# Nearest to 'american': and, foreshadowing, english, canadian,
# Nearest to 'would': could, may, to, hardly,
# Nearest to 'or': and, dasyprocta, operatorname, amalthea,
# Nearest to 'from': in, of, for, with,
# Nearest to 'by': was, in, dasyprocta, with,
# Nearest to 'their': its, the, his, all,
# Nearest to 'his': the, their, s, her,
# Nearest to 'have': were, has, are, had,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': refuse, most, headquarters, a,
# Nearest to 'use': phi, orestes, mishnayot, conclusions,
#
# Average loss at step  30000 :  5.926218111872673
# Nearest to 'that': which, dasyprocta, operatorname, communism,
# Nearest to 'after': circ, archie, seven, of,
# Nearest to 's': and, zero, amalthea, the,
# Nearest to 'other': celebrates, pcm, airshows, meridians,
# Nearest to 'american': and, english, foreshadowing, canadian,
# Nearest to 'would': could, may, to, can,
# Nearest to 'or': and, dasyprocta, operatorname, amalthea,
# Nearest to 'from': in, with, before, for,
# Nearest to 'by': in, was, dasyprocta, with,
# Nearest to 'their': the, its, his, all,
# Nearest to 'his': the, their, s, her,
# Nearest to 'have': were, has, are, be,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': refuse, most, headquarters, even,
# Nearest to 'use': phi, orestes, mishnayot, conclusions,
#
# Average loss at step  32000 :  6.018336333155632
# Nearest to 'that': which, dasyprocta, operatorname, communism,
# Nearest to 'after': in, archie, circ, of,
# Nearest to 's': and, zero, amalthea, or,
# Nearest to 'other': pcm, celebrates, meridians, airshows,
# Nearest to 'american': english, and, foreshadowing, canadian,
# Nearest to 'would': could, may, can, to,
# Nearest to 'or': and, dasyprocta, operatorname, archie,
# Nearest to 'from': in, and, on, before,
# Nearest to 'by': in, was, dasyprocta, and,
# Nearest to 'their': its, the, his, all,
# Nearest to 'his': their, the, s, her,
# Nearest to 'have': were, has, are, had,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': refuse, most, headquarters, ate,
# Nearest to 'use': orestes, phi, mishnayot, operatorname,
#
# Average loss at step  34000 :  5.741314570307732
# Nearest to 'that': which, dasyprocta, operatorname, direct,
# Nearest to 'after': circ, in, archie, algeria,
# Nearest to 's': zero, and, amalthea, his,
# Nearest to 'other': celebrates, pcm, gum, meridians,
# Nearest to 'american': and, english, foreshadowing, canadian,
# Nearest to 'would': could, may, can, to,
# Nearest to 'or': and, dasyprocta, operatorname, archie,
# Nearest to 'from': in, and, before, on,
# Nearest to 'by': was, dasyprocta, in, were,
# Nearest to 'their': its, the, his, all,
# Nearest to 'his': their, the, s, her,
# Nearest to 'have': were, has, are, had,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, has, are, were,
# Nearest to 'more': refuse, most, headquarters, less,
# Nearest to 'use': phi, orestes, mishnayot, operatorname,
#
# Average loss at step  36000 :  5.762409910798072
# Nearest to 'that': which, dasyprocta, operatorname, this,
# Nearest to 'after': circ, in, archie, powdered,
# Nearest to 's': and, zero, his, amalthea,
# Nearest to 'other': celebrates, pcm, gum, airshows,
# Nearest to 'american': english, foreshadowing, and, canadian,
# Nearest to 'would': could, may, can, to,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, on, and, before,
# Nearest to 'by': was, dasyprocta, were, in,
# Nearest to 'their': its, the, his, all,
# Nearest to 'his': the, their, her, s,
# Nearest to 'have': were, has, are, be,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': most, refuse, headquarters, less,
# Nearest to 'use': phi, orestes, forti, mishnayot,
#
# Average loss at step  38000 :  5.566685090184212
# Nearest to 'that': which, dasyprocta, this, operatorname,
# Nearest to 'after': in, archie, circ, algeria,
# Nearest to 's': and, zero, his, the,
# Nearest to 'other': gum, celebrates, pcm, many,
# Nearest to 'american': and, english, foreshadowing, canadian,
# Nearest to 'would': could, may, can, to,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, on, and, before,
# Nearest to 'by': was, with, dasyprocta, is,
# Nearest to 'their': its, his, the, all,
# Nearest to 'his': their, the, her, s,
# Nearest to 'have': were, has, are, had,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, are, has, dasyprocta,
# Nearest to 'more': most, refuse, less, headquarters,
# Nearest to 'use': phi, orestes, forti, mishnayot,
#
# Average loss at step  40000 :  5.2988223310709
# Nearest to 'that': which, dasyprocta, this, operatorname,
# Nearest to 'after': in, circ, archie, seven,
# Nearest to 's': zero, and, his, amalthea,
# Nearest to 'other': gum, pcm, celebrates, many,
# Nearest to 'american': and, english, foreshadowing, canadian,
# Nearest to 'would': may, could, can, to,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, on, with, before,
# Nearest to 'by': was, dasyprocta, in, with,
# Nearest to 'their': its, his, the, all,
# Nearest to 'his': their, the, her, s,
# Nearest to 'have': were, has, are, had,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, are, has, were,
# Nearest to 'more': most, refuse, less, headquarters,
# Nearest to 'use': phi, orestes, one, mishnayot,
#
# Average loss at step  42000 :  5.3740971990823745
# Nearest to 'that': which, dasyprocta, this, operatorname,
# Nearest to 'after': circ, archie, in, seven,
# Nearest to 's': his, zero, and, agave,
# Nearest to 'other': many, pcm, celebrates, gum,
# Nearest to 'american': and, english, canadian, foreshadowing,
# Nearest to 'would': may, could, can, will,
# Nearest to 'or': and, dasyprocta, operatorname, amalthea,
# Nearest to 'from': in, on, before, with,
# Nearest to 'by': was, dasyprocta, with, agouti,
# Nearest to 'their': its, his, the, all,
# Nearest to 'his': their, the, s, her,
# Nearest to 'have': were, has, are, had,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, are, has, dasyprocta,
# Nearest to 'more': most, refuse, less, very,
# Nearest to 'use': phi, orestes, operatorname, mishnayot,
#
# Average loss at step  44000 :  5.255595411300659
# Nearest to 'that': which, dasyprocta, operatorname, this,
# Nearest to 'after': in, circ, archie, of,
# Nearest to 's': his, zero, the, and,
# Nearest to 'other': many, gum, occurrence, celebrates,
# Nearest to 'american': and, english, canadian, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, before, on, with,
# Nearest to 'by': was, dasyprocta, with, as,
# Nearest to 'their': its, his, the, archie,
# Nearest to 'his': their, the, her, s,
# Nearest to 'have': were, has, had, are,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, has, are, were,
# Nearest to 'more': most, less, refuse, very,
# Nearest to 'use': phi, orestes, mishnayot, operatorname,
#
# Average loss at step  46000 :  5.198060728669167
# Nearest to 'that': which, dasyprocta, this, but,
# Nearest to 'after': and, circ, archie, in,
# Nearest to 's': his, zero, and, cardinality,
# Nearest to 'other': many, gum, celebrates, occurrence,
# Nearest to 'american': english, canadian, and, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, before, with, on,
# Nearest to 'by': was, dasyprocta, as, with,
# Nearest to 'their': its, his, the, archie,
# Nearest to 'his': their, the, her, s,
# Nearest to 'have': were, has, had, are,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, has, are, were,
# Nearest to 'more': most, less, refuse, very,
# Nearest to 'use': phi, orestes, mishnayot, operatorname,
#
# Average loss at step  48000 :  5.243140290498734
# Nearest to 'that': which, dasyprocta, but, this,
# Nearest to 'after': circ, archie, in, teen,
# Nearest to 's': the, his, and, zero,
# Nearest to 'other': many, gum, occurrence, celebrates,
# Nearest to 'american': english, and, canadian, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, with, before, into,
# Nearest to 'by': was, dasyprocta, as, in,
# Nearest to 'their': its, his, the, archie,
# Nearest to 'his': their, the, her, s,
# Nearest to 'have': were, has, had, are,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, are, has, rhetoric,
# Nearest to 'more': most, less, refuse, very,
# Nearest to 'use': phi, mishnayot, orestes, operatorname,
#
# Average loss at step  50000 :  4.982212780475616
# Nearest to 'that': which, dasyprocta, this, operatorname,
# Nearest to 'after': circ, teen, archie, powdered,
# Nearest to 's': zero, and, his, of,
# Nearest to 'other': many, occurrence, gum, celebrates,
# Nearest to 'american': english, canadian, and, international,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, before, into, on,
# Nearest to 'by': was, dasyprocta, in, from,
# Nearest to 'their': its, his, the, archie,
# Nearest to 'his': their, the, her, its,
# Nearest to 'have': were, has, had, are,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, has, are, were,
# Nearest to 'more': most, less, refuse, very,
# Nearest to 'use': phi, achish, mishnayot, orestes,
#
# Average loss at step  52000 :  5.03583032310009
# Nearest to 'that': which, joram, dasyprocta, operatorname,
# Nearest to 'after': circ, teen, archie, operatorname,
# Nearest to 's': zero, and, his, cardinality,
# Nearest to 'other': many, occurrence, gum, different,
# Nearest to 'american': english, and, canadian, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, operatorname, kapoor,
# Nearest to 'from': in, before, on, into,
# Nearest to 'by': was, dasyprocta, as, be,
# Nearest to 'their': its, his, the, archie,
# Nearest to 'his': their, the, her, its,
# Nearest to 'have': were, has, had, are,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, has, are, dasyprocta,
# Nearest to 'more': most, less, refuse, very,
# Nearest to 'use': phi, mishnayot, achish, orestes,
#
# Average loss at step  54000 :  5.208552256941795
# Nearest to 'that': which, joram, dasyprocta, cem,
# Nearest to 'after': circ, teen, before, wct,
# Nearest to 's': zero, his, four, amalthea,
# Nearest to 'other': many, occurrence, different, gum,
# Nearest to 'american': english, canadian, international, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, operatorname, circ,
# Nearest to 'from': in, into, before, on,
# Nearest to 'by': was, dasyprocta, during, with,
# Nearest to 'their': its, his, the, all,
# Nearest to 'his': their, the, her, its,
# Nearest to 'have': were, had, has, are,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, has, are, rhetoric,
# Nearest to 'more': most, less, refuse, very,
# Nearest to 'use': achish, orestes, mishnayot, phi,
#
# Average loss at step  56000 :  5.0321405305862426
# Nearest to 'that': which, joram, dasyprocta, cem,
# Nearest to 'after': circ, before, teen, archie,
# Nearest to 's': zero, his, and, cardinality,
# Nearest to 'other': many, different, occurrence, gum,
# Nearest to 'american': and, english, international, canadian,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, circ, operatorname,
# Nearest to 'from': in, into, before, at,
# Nearest to 'by': was, dasyprocta, during, be,
# Nearest to 'their': its, his, the, archie,
# Nearest to 'his': their, her, the, its,
# Nearest to 'have': were, had, has, are,
# Nearest to 'no': a, still, amalthea, ask,
# Nearest to 'is': was, has, are, rhetoric,
# Nearest to 'more': most, less, refuse, very,
# Nearest to 'use': achish, mishnayot, orestes, phi,
#
# Average loss at step  58000 :  5.0584367084503175
# Nearest to 'that': which, joram, dasyprocta, cem,
# Nearest to 'after': before, circ, archie, wct,
# Nearest to 's': his, zero, and, cardinality,
# Nearest to 'other': many, different, occurrence, gum,
# Nearest to 'american': english, and, canadian, international,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, michelob, operatorname,
# Nearest to 'from': in, into, before, at,
# Nearest to 'by': was, dasyprocta, be, during,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, the, her, its,
# Nearest to 'have': were, had, has, are,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, has, are, dasyprocta,
# Nearest to 'more': most, less, very, refuse,
# Nearest to 'use': achish, mishnayot, phi, orestes,
#
# Average loss at step  60000 :  4.959482067108154
# Nearest to 'that': which, joram, dasyprocta, this,
# Nearest to 'after': before, circ, when, archie,
# Nearest to 's': zero, his, and, amalthea,
# Nearest to 'other': many, different, gum, occurrence,
# Nearest to 'american': english, and, canadian, international,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, michelob, circ,
# Nearest to 'from': in, into, before, at,
# Nearest to 'by': was, during, dasyprocta, be,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': a, still, amalthea, it,
# Nearest to 'is': was, has, are, dasyprocta,
# Nearest to 'more': most, less, very, refuse,
# Nearest to 'use': pulau, achish, mishnayot, intersection,
#
# Average loss at step  62000 :  5.003174213886261
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, during, microcebus,
# Nearest to 's': his, and, zero, cebus,
# Nearest to 'other': many, different, gum, occurrence,
# Nearest to 'american': english, canadian, and, international,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, cebus, dasyprocta, operatorname,
# Nearest to 'from': in, into, and, before,
# Nearest to 'by': was, during, be, dasyprocta,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, the, its,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': a, amalthea, still, it,
# Nearest to 'is': was, are, has, rhetoric,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': pulau, intersection, achish, mishnayot,
#
# Average loss at step  64000 :  4.845394467413425
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, microcebus, circ,
# Nearest to 's': zero, his, and, cebus,
# Nearest to 'other': many, different, gum, occurrence,
# Nearest to 'american': english, and, canadian, international,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, dasyprocta, cebus, operatorname,
# Nearest to 'from': in, into, before, and,
# Nearest to 'by': was, during, dasyprocta, be,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': has, had, were, are,
# Nearest to 'no': amalthea, still, a, kapoor,
# Nearest to 'is': was, are, has, rhetoric,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': pulau, intersection, achish, mishnayot,
#
# Average loss at step  66000 :  4.589793541550637
# Nearest to 'that': which, this, joram, dasyprocta,
# Nearest to 'after': before, when, during, microcebus,
# Nearest to 's': zero, his, cebus, cardinality,
# Nearest to 'other': many, gum, some, different,
# Nearest to 'american': english, canadian, international, and,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, operatorname, cebus, dasyprocta,
# Nearest to 'from': in, into, before, on,
# Nearest to 'by': was, dasyprocta, during, be,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': has, had, were, are,
# Nearest to 'no': amalthea, still, a, ask,
# Nearest to 'is': was, has, are, rhetoric,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': pulau, intersection, mishnayot, achish,
#
# Average loss at step  68000 :  4.9767855696678165
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, microcebus, circ,
# Nearest to 's': his, cardinality, cebus, zero,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': english, canadian, international, microsite,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, cebus, operatorname, circ,
# Nearest to 'from': in, into, before, at,
# Nearest to 'by': was, be, dasyprocta, during,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': a, amalthea, still, ask,
# Nearest to 'is': was, are, has, rhetoric,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': pulau, intersection, achish, mishnayot,
#
# Average loss at step  70000 :  4.8977279669046405
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, during, microcebus,
# Nearest to 's': his, and, cardinality, cebus,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': english, canadian, international, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, cebus, operatorname, dasyprocta,
# Nearest to 'from': in, into, before, at,
# Nearest to 'by': was, be, during, dasyprocta,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, the, its,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': a, amalthea, still, ask,
# Nearest to 'is': was, are, has, rhetoric,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': pulau, intersection, achish, mishnayot,
#
# Average loss at step  72000 :  4.756602712869644
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, during, microcebus,
# Nearest to 's': and, cebus, cardinality, his,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': english, canadian, international, microsite,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, cebus, operatorname, dasyprocta,
# Nearest to 'from': in, into, before, on,
# Nearest to 'by': was, dasyprocta, during, be,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': a, amalthea, still, it,
# Nearest to 'is': was, are, has, dasyprocta,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': intersection, pulau, achish, mishnayot,
#
# Average loss at step  74000 :  4.795568760037423
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, during, in,
# Nearest to 's': and, his, cebus, cardinality,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': english, canadian, international, foreshadowing,
# Nearest to 'would': could, may, will, can,
# Nearest to 'or': and, cebus, operatorname, dasyprocta,
# Nearest to 'from': into, in, before, on,
# Nearest to 'by': was, during, be, dasyprocta,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': a, amalthea, still, it,
# Nearest to 'is': was, are, has, dasyprocta,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': intersection, achish, pulau, mishnayot,
#
# Average loss at step  76000 :  4.739501511216163
# Nearest to 'that': which, joram, dasyprocta, this,
# Nearest to 'after': before, when, during, in,
# Nearest to 's': his, cebus, and, amalthea,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': english, canadian, international, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, cebus, operatorname, dasyprocta,
# Nearest to 'from': in, into, of, before,
# Nearest to 'by': was, be, during, dasyprocta,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, the, its,
# Nearest to 'have': had, were, has, are,
# Nearest to 'no': amalthea, a, still, kapoor,
# Nearest to 'is': was, are, has, dasyprocta,
# Nearest to 'more': less, most, very, even,
# Nearest to 'use': intersection, pulau, achish, mishnayot,
#
# Average loss at step  78000 :  4.802186121195555
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, during, circ,
# Nearest to 's': cebus, his, amalthea, microcebus,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': canadian, english, international, foreshadowing,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, cebus, operatorname, dasyprocta,
# Nearest to 'from': into, in, on, before,
# Nearest to 'by': was, be, dasyprocta, during,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, were, has, are,
# Nearest to 'no': amalthea, still, a, it,
# Nearest to 'is': was, has, are, dasyprocta,
# Nearest to 'more': less, most, very, refuse,
# Nearest to 'use': traumas, intersection, pulau, achish,
#
# Average loss at step  80000 :  4.806547584176063
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, during, microcebus,
# Nearest to 's': his, cebus, zero, amalthea,
# Nearest to 'other': many, different, some, gum,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, may, can, will,
# Nearest to 'or': and, cebus, operatorname, circ,
# Nearest to 'from': in, into, through, on,
# Nearest to 'by': was, dasyprocta, during, be,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, the, its,
# Nearest to 'have': had, were, has, are,
# Nearest to 'no': amalthea, still, a, it,
# Nearest to 'is': was, has, are, rhetoric,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, escuela, achish,
#
# Average loss at step  82000 :  4.758875813484192
# Nearest to 'that': which, joram, this, dasyprocta,
# Nearest to 'after': before, when, during, microcebus,
# Nearest to 's': his, cebus, the, microcebus,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': canadian, english, international, and,
# Nearest to 'would': could, can, will, may,
# Nearest to 'or': and, cebus, operatorname, thaler,
# Nearest to 'from': into, in, through, at,
# Nearest to 'by': six, dasyprocta, was, nine,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, the, its,
# Nearest to 'have': had, were, has, are,
# Nearest to 'no': amalthea, still, a, kapoor,
# Nearest to 'is': was, has, are, dasyprocta,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, escuela, achish,
#
# Average loss at step  84000 :  4.767438676118851
# Nearest to 'that': which, joram, dasyprocta, this,
# Nearest to 'after': before, when, during, microcebus,
# Nearest to 's': his, cebus, zero, microcebus,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': canadian, english, international, and,
# Nearest to 'would': could, will, can, may,
# Nearest to 'or': and, cebus, operatorname, thaler,
# Nearest to 'from': in, into, at, through,
# Nearest to 'by': was, dasyprocta, during, be,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, the, its,
# Nearest to 'have': had, were, has, are,
# Nearest to 'no': amalthea, still, a, kapoor,
# Nearest to 'is': was, has, are, rhetoric,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, escuela, pulau,
#
# Average loss at step  86000 :  4.775187309980392
# Nearest to 'that': which, joram, however, dasyprocta,
# Nearest to 'after': before, when, during, in,
# Nearest to 's': cebus, five, his, amalthea,
# Nearest to 'other': many, some, different, gum,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, can, may, will,
# Nearest to 'or': and, operatorname, cebus, thaler,
# Nearest to 'from': in, into, at, through,
# Nearest to 'by': dasyprocta, as, was, during,
# Nearest to 'their': its, his, the, michelob,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, were, has, are,
# Nearest to 'no': amalthea, still, a, kapoor,
# Nearest to 'is': was, has, are, dasyprocta,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, escuela, pulau,
#
# Average loss at step  88000 :  4.756001564621926
# Nearest to 'that': which, joram, however, this,
# Nearest to 'after': before, when, during, peacocks,
# Nearest to 's': his, cebus, zero, microcebus,
# Nearest to 'other': some, different, many, gum,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, can, may, will,
# Nearest to 'or': and, operatorname, cebus, dasyprocta,
# Nearest to 'from': into, in, at, through,
# Nearest to 'by': was, dasyprocta, during, as,
# Nearest to 'their': its, his, the, her,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': amalthea, still, a, kapoor,
# Nearest to 'is': was, has, are, peacocks,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, escuela, pulau,
#
# Average loss at step  90000 :  4.724662171125412
# Nearest to 'that': which, joram, this, however,
# Nearest to 'after': before, when, during, peacocks,
# Nearest to 's': his, and, cebus, six,
# Nearest to 'other': some, different, many, gum,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, will, can, may,
# Nearest to 'or': and, operatorname, cebus, dasyprocta,
# Nearest to 'from': into, in, at, through,
# Nearest to 'by': was, dasyprocta, as, during,
# Nearest to 'their': its, his, the, her,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': amalthea, a, still, kapoor,
# Nearest to 'is': was, has, are, peacocks,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, escuela, mishnayot,
#
# Average loss at step  92000 :  4.672800813913345
# Nearest to 'that': which, joram, this, but,
# Nearest to 'after': before, when, during, peacocks,
# Nearest to 's': cebus, his, and, cardinality,
# Nearest to 'other': different, some, many, gum,
# Nearest to 'american': canadian, english, international, foreshadowing,
# Nearest to 'would': could, will, can, may,
# Nearest to 'or': and, operatorname, cebus, dasyprocta,
# Nearest to 'from': into, in, at, through,
# Nearest to 'by': during, was, dasyprocta, in,
# Nearest to 'their': its, his, the, her,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': amalthea, a, still, it,
# Nearest to 'is': was, has, are, peacocks,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, pulau, escuela,
#
# Average loss at step  94000 :  4.724589199066162
# Nearest to 'that': which, joram, dasyprocta, this,
# Nearest to 'after': before, when, during, peacocks,
# Nearest to 's': his, cebus, cardinality, amalthea,
# Nearest to 'other': different, some, many, gum,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, will, may, can,
# Nearest to 'or': and, operatorname, cebus, dasyprocta,
# Nearest to 'from': into, in, through, at,
# Nearest to 'by': during, dasyprocta, was, with,
# Nearest to 'their': its, his, the, her,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': amalthea, still, a, it,
# Nearest to 'is': was, has, are, peacocks,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, escuela, pulau,
#
# Average loss at step  96000 :  4.680393314242363
# Nearest to 'that': which, joram, this, however,
# Nearest to 'after': before, during, when, peacocks,
# Nearest to 's': his, zero, cebus, and,
# Nearest to 'other': different, some, gum, many,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, will, may, can,
# Nearest to 'or': and, operatorname, cebus, dasyprocta,
# Nearest to 'from': into, in, through, at,
# Nearest to 'by': during, dasyprocta, was, be,
# Nearest to 'their': its, his, the, her,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': amalthea, a, still, kapoor,
# Nearest to 'is': was, has, are, peacocks,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': traumas, intersection, pulau, escuela,
#
# Average loss at step  98000 :  4.608312906861305
# Nearest to 'that': which, joram, this, however,
# Nearest to 'after': before, during, when, peacocks,
# Nearest to 's': cebus, ursus, microcebus, operatorname,
# Nearest to 'other': different, gum, some, many,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, will, can, may,
# Nearest to 'or': and, cebus, operatorname, circ,
# Nearest to 'from': into, in, through, at,
# Nearest to 'by': during, dasyprocta, be, was,
# Nearest to 'their': its, his, the, her,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': amalthea, a, still, kapoor,
# Nearest to 'is': was, has, are, rhetoric,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': intersection, traumas, escuela, pulau,
#
# Average loss at step  100000 :  4.699468890428543
# Nearest to 'that': which, joram, this, what,
# Nearest to 'after': before, when, during, peacocks,
# Nearest to 's': his, cebus, microcebus, and,
# Nearest to 'other': different, some, gum, many,
# Nearest to 'american': canadian, english, international, microsite,
# Nearest to 'would': could, will, can, may,
# Nearest to 'or': and, cebus, operatorname, dasyprocta,
# Nearest to 'from': in, into, through, at,
# Nearest to 'by': was, during, be, dasyprocta,
# Nearest to 'their': its, his, the, her,
# Nearest to 'his': their, her, its, the,
# Nearest to 'have': had, has, were, are,
# Nearest to 'no': amalthea, a, still, niels,
# Nearest to 'is': was, has, are, became,
# Nearest to 'more': less, most, very, pontificia,
# Nearest to 'use': intersection, traumas, runic, pulau,

# %% [markdown]
# <center><img src="../images/watiing.jpg" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings with t-SNE.
# ----

# %% [markdown]
# In this step, we use the t-SNE algorithm to reduce the dimensionality of the learned word embeddings for visualization.
#
# The top 500 words (based on frequency) are plotted in a 2D space, allowing us to visually inspect the relationships and groupings among words.
#
# This visualization is a powerful tool to understand how well the model has learned semantic relationships.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            max_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ------
#
# # Let's render and plot more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='../images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', max_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# # And voila!
#
# Now you have a visual understanding of embeddings.

# %% [markdown]
# Thank you for following this tutorial!
